# %%
from curve_completor import CompletingCurve

# %%
completor=CompletingCurve(file_path=r"data/occlusion1.csv")
# Out:
# 1 contours are found
# 2 contours are found

# %%
# completor.regularize_line()

# %%
completor.regularize_curve()
